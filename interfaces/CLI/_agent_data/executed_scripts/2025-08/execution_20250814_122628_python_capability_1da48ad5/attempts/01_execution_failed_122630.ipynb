# %% [markdown]
# # Python Executor - Attempt #1
#
# **Stage:** execution_failed
# **Created:** 2025-08-14 12:26:30
#
# ## Error Context
#
# **Error:** Missing Module: 'framework' not available in Python environment
# 💡 SOLUTION: Add framework to your Python environment:
#    /Users/magarces/test/alpha_berkeley/venv/bin/python -m pip install framework
#
# **Full Traceback:**
# ```
# Traceback (most recent call last):
#   File "/Users/magarces/test/alpha_berkeley/interfaces/CLI/../../src/framework/services/python_executor/executor_node.py", line 467, in executor_node
#     execution_result = await executor.execute_code(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/magarces/test/alpha_berkeley/interfaces/CLI/../../src/framework/services/python_executor/executor_node.py", line 57, in execute_code
#     return await self._execute_with_subprocess(wrapped_code, execution_folder)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/magarces/test/alpha_berkeley/interfaces/CLI/../../src/framework/services/python_executor/executor_node.py", line 126, in _execute_with_subprocess
#     raise CodeRuntimeError(
# framework.services.python_executor.exceptions.CodeRuntimeError: Missing Module: 'framework' not available in Python environment
# 💡 SOLUTION: Add framework to your Python environment:
#    /Users/magarces/test/alpha_berkeley/venv/bin/python -m pip install framework
#
# ```
#
# **Execution Stage:** Code execution failed during wrapped code execution
#
# **Debug Information:**
# - Error Type: CodeRuntimeError
# - Error Message: Missing Module: 'framework' not available in Python environment
# 💡 SOLUTION: Add framework to your Python environment:
#    /Users/magarces/test/alpha_berkeley/venv/bin/python -m pip install framework
# - Generated Code Length: 1225 characters

# %%
# Load execution context
from framework.context import load_context
context = load_context('../context.json')

# %%
import cv2
import numpy as np
import json

def extract_measurement_data(image_path):
    # Initialize results dictionary
    results = {}
    
    try:
        # Read the image
        image = cv2.imread(image_path)
        
        # Check if image was loaded successfully
        if image is None:
            results['error'] = 'Unable to load image'
            return results
        
        # Convert to grayscale for analysis
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        
        # Basic image measurements
        results['height'] = image.shape[0]
        results['width'] = image.shape[1]
        results['channels'] = image.shape[2] if len(image.shape) > 2 else 1
        
        # Compute pixel statistics
        results['mean_pixel_intensity'] = np.mean(gray_image)
        results['std_pixel_intensity'] = np.std(gray_image)
        results['min_pixel_intensity'] = np.min(gray_image)
        results['max_pixel_intensity'] = np.max(gray_image)
        
        return results
    
    except Exception as e:
        results['error'] = str(e)
        return results

# Save results for context accessibility
results = extract_measurement_data(context.DETECTOR_IMAGE.measurement_image)
